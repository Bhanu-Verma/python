# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
    #ALL ABOUT INDEXES IN A DATAFRAME
df=pd.read_csv('survey_results_public.csv')
schema_df=pd.read_csv('survey_results_schema.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist
# 0               1             I am a student who is learning to code      Yes  \
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.set_index('Hobbyist',inplace=True)   #it doesnt really change so inplace = true

df
# Out:
#           Respondent                                         MainBranch
# Hobbyist
# Yes                1             I am a student who is learning to code  \
# No                 2             I am a student who is learning to code
# Yes                3  I am not primarily a developer, but I write co...
# No                 4                     I am a developer by profession
# Yes                5                     I am a developer by profession
# ...              ...                                                ...
# Yes            88377                                                NaN
# No             88601                                                NaN
# No             88802                                                NaN
# No             88816                                                NaN
# Yes            88863                                                NaN
#
#                                                 OpenSourcer
# Hobbyist
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#       Hobbyist  Respondent                                         MainBranch
# 0          Yes           1             I am a student who is learning to code  \
# 1           No           2             I am a student who is learning to code
# 2          Yes           3  I am not primarily a developer, but I write co...
# 3           No           4                     I am a developer by profession
# 4          Yes           5                     I am a developer by profession
# ...        ...         ...                                                ...
# 88878      Yes       88377                                                NaN
# 88879       No       88601                                                NaN
# 88880       No       88802                                                NaN
# 88881       No       88816                                                NaN
# 88882      Yes       88863                                                NaN
#
# ...

# %%
#here respondent column is itself an indexing so we should try to use it efficiently
#to do this while reading the csv file we should pass another argument of the index_col

# %%
#FILTERING THE DATA USING PANDAS
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
#suppose we want to filterout only the hobbyist ons
df.reset_index(inplace=True)
df
# Out:
#        index Hobbyist  Respondent
# 0          0      Yes           1  \
# 1          1       No           2
# 2          2      Yes           3
# 3          3       No           4
# 4          4      Yes           5
# ...      ...      ...         ...
# 88878  88878      Yes       88377
# 88879  88879       No       88601
# 88880  88880       No       88802
# 88881  88881       No       88816
# 88882  88882      Yes       88863
#
#                                               MainBranch
# 0                 I am a student who is learning to code  \
# 1                 I am a student who is learning to code
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# ...

# %%
df.drop('index',axis=1)
# Out:
#       Hobbyist  Respondent                                         MainBranch
# 0          Yes           1             I am a student who is learning to code  \
# 1           No           2             I am a student who is learning to code
# 2          Yes           3  I am not primarily a developer, but I write co...
# 3           No           4                     I am a developer by profession
# 4          Yes           5                     I am a developer by profession
# ...        ...         ...                                                ...
# 88878      Yes       88377                                                NaN
# 88879       No       88601                                                NaN
# 88880       No       88802                                                NaN
# 88881       No       88816                                                NaN
# 88882      Yes       88863                                                NaN
#
# ...

# %%
#explicit filter
filt= df['Hobbyist']=='Yes'   #filt is a list that will contain booleans
df[filt]
# Out:
#        index Hobbyist  Respondent
# 0          0      Yes           1  \
# 2          2      Yes           3
# 4          4      Yes           5
# 5          5      Yes           6
# 7          7      Yes           8
# ...      ...      ...         ...
# 88872  88872      Yes       87739
# 88875  88875      Yes       88182
# 88877  88877      Yes       88282
# 88878  88878      Yes       88377
# 88882  88882      Yes       88863
#
#                                               MainBranch
# 0                 I am a student who is learning to code  \
# 2      I am not primarily a developer, but I write co...
# 4                         I am a developer by profession
# 5      I am not primarily a developer, but I write co...
# 7                            I code primarily as a hobby
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# ...

# %%
#inplace filter
df[df['Hobbyist']=='Yes']   #it doesn't change the content of real df
# Out:
#        index Hobbyist  Respondent
# 0          0      Yes           1  \
# 2          2      Yes           3
# 4          4      Yes           5
# 5          5      Yes           6
# 7          7      Yes           8
# ...      ...      ...         ...
# 88872  88872      Yes       87739
# 88875  88875      Yes       88182
# 88877  88877      Yes       88282
# 88878  88878      Yes       88377
# 88882  88882      Yes       88863
#
#                                               MainBranch
# 0                 I am a student who is learning to code  \
# 2      I am not primarily a developer, but I write co...
# 4                         I am a developer by profession
# 5      I am not primarily a developer, but I write co...
# 7                            I code primarily as a hobby
# ...                                                  ...
# 88872                                                NaN
# 88875                                                NaN
# ...

# %%
#boolean operators are as follows-
# and -- &
#or -- |
#not -- ~

#our task is to filter the one who is hobbyist but not an opensourcer
filt=(df['Hobbyist']=='Yes') & (df['OpenSourcer']=='Never')
df[filt]
# Out:
#        index Hobbyist  Respondent
# 0          0      Yes           1  \
# 2          2      Yes           3
# 5          5      Yes           6
# 14        14      Yes          15
# 15        15      Yes          16
# ...      ...      ...         ...
# 88839  88839      Yes       82134
# 88846  88846      Yes       83612
# 88853  88853      Yes       84299
# 88860  88860      Yes       85738
# 88866  88866      Yes       86638
#
#                                               MainBranch OpenSourcer
# 0                 I am a student who is learning to code       Never  \
# 2      I am not primarily a developer, but I write co...       Never
# 5      I am not primarily a developer, but I write co...       Never
# 14                I am a student who is learning to code       Never
# 15                        I am a developer by profession       Never
# ...                                                  ...         ...
# ...

# %%
#suppose we want to compare the number of hobbyists of united states and united kindoms
filt1=(df['Hobbyist']=='Yes') & (df['Country']=='United States')

#method mentioned below is too much powerful
#it filters the paased arguments in the second bracket
df.loc[filt1,['index']]
# Out:
#        index
# 12        12
# 21        21
# 22        22
# 25        25
# 28        28
# ...      ...
# 88797  88797
# 88810  88810
# 88811  88811
# 88844  88844
# 88877  88877
#
# [16839 rows x 1 columns]

# %%
#TO UPDATE ROWS AND COLUMNS NAME
    #we can just simply use the assignment with df.columns
#df.columns=range(86)  #this will change the columns names
#df.columns

# %%
df.head(6)
# Out:
#    index Hobbyist  Respondent
# 0      0      Yes           1  \
# 1      1       No           2
# 2      2      Yes           3
# 3      3       No           4
# 4      4      Yes           5
# 5      5      Yes           6
#
#                                           MainBranch
# 0             I am a student who is learning to code  \
# 1             I am a student who is learning to code
# 2  I am not primarily a developer, but I write co...
# 3                     I am a developer by profession
# 4                     I am a developer by profession
# 5  I am not primarily a developer, but I write co...
#
#                   OpenSourcer
# 0                       Never  \
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
#
#                                           OpenSource
# 0  The quality of OSS and closed source software ...  \
# ...

# %%
#to change the country of idx5 from Canada to Uk
df.iloc[5]
# Out:
# index                                                           5
# Hobbyist                                                      Yes
# Respondent                                                      6
# MainBranch      I am not primarily a developer, but I write co...
# OpenSourcer                                                 Never
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                              East Asian
# Dependents                                                     No
# SurveyLength                                             Too long
# SurveyEase                             Neither easy nor difficult
# Name: 5, Length: 86, dtype: object

# %%
df.iloc[5,7]='Uk'   #this change is inplace
df.head(6)
# Out:
#    index Hobbyist  Respondent
# 0      0      Yes           1  \
# 1      1       No           2
# 2      2      Yes           3
# 3      3       No           4
# 4      4      Yes           5
# 5      5      Yes           6
#
#                                           MainBranch
# 0             I am a student who is learning to code  \
# 1             I am a student who is learning to code
# 2  I am not primarily a developer, but I write co...
# 3                     I am a developer by profession
# 4                     I am a developer by profession
# 5  I am not primarily a developer, but I write co...
#
#                   OpenSourcer
# 0                       Never  \
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
#
#                                           OpenSource
# 0  The quality of OSS and closed source software ...  \
# ...

# %%
#if we try to change the content of dataframe without using that loc then it will not work

# %%
#updating multiple rows at single time
  #SUPPOSE WE WANT TO MAKE THE COLULMN INDEXED ONE LOWER CASE ONLY
df['Hobbyist']=df['Hobbyist'].str.lower()
df.head(3)
# Out:
#    index Hobbyist  Respondent
# 0      0      yes           1  \
# 1      1       no           2
# 2      2      yes           3
#
#                                           MainBranch              OpenSourcer
# 0             I am a student who is learning to code                    Never  \
# 1             I am a student who is learning to code  Less than once per year
# 2  I am not primarily a developer, but I write co...                    Never
#
#                                           OpenSource
# 0  The quality of OSS and closed source software ...  \
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment                 Country
# 0  Not employed, and not looking for work          United Kingdom  \
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
# ...

# %%
#THERE ARE FOUR CLOSE METHODS--
  # apply
  # map
  # applymap
  # replace

  #apply--- used for calling a function for each element of a data frame or a series
    #here we want to find the length of hobbyist
df['Hobbyist'].apply(len) #here function is passed without paranthesis apply will make it a finction itself
# Out:
# 0        3
# 1        2
# 2        3
# 3        2
# 4        3
#         ..
# 88878    3
# 88879    2
# 88880    2
# 88881    2
# 88882    3
# Name: Hobbyist, Length: 88883, dtype: int64

# %%
df.apply(len)   #this function is appllied on all the columns of the data frame
# Out:
# index           88883
# Hobbyist        88883
# Respondent      88883
# MainBranch      88883
# OpenSourcer     88883
#                 ...
# Sexuality       88883
# Ethnicity       88883
# Dependents      88883
# SurveyLength    88883
# SurveyEase      88883
# Length: 86, dtype: int64

# %%
#APPLYMAP -- only works on dataframe, series don't have it, it applies a funciton to each indivisual value of df
def nothing(x):
  return
df.applymap(nothing)    #it applies nothing function to all the elements
# Out:
#       index Hobbyist Respondent MainBranch OpenSourcer OpenSource Employment
# 0      None     None       None       None        None       None       None  \
# 1      None     None       None       None        None       None       None
# 2      None     None       None       None        None       None       None
# 3      None     None       None       None        None       None       None
# 4      None     None       None       None        None       None       None
# ...     ...      ...        ...        ...         ...        ...        ...
# 88878  None     None       None       None        None       None       None
# 88879  None     None       None       None        None       None       None
# 88880  None     None       None       None        None       None       None
# 88881  None     None       None       None        None       None       None
# 88882  None     None       None       None        None       None       None
#
# ...

# %%
#MAP -- only works on the series ONLY FOR SUBSTITUTING EACH VALUE IN A SEREIS
#here we pass a dictionary of values that we want to substitue
df['Student'].map({'No':'False'})   #what vlues we don't pass it converts them to Nan
                                    #convert all the No to false
# Out:
# 0        False
# 1          NaN
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879      NaN
# 88880      NaN
# 88881      NaN
# 88882      NaN
# Name: Student, Length: 88883, dtype: object

# %%
# to change the column name we can use the following way--
df.rename(columns={'Hobbyist':'bool'})    #it's not really changing the content of the dataframe
# Out:
#        index bool  Respondent
# 0          0  yes           1  \
# 1          1   no           2
# 2          2  yes           3
# 3          3   no           4
# 4          4  yes           5
# ...      ...  ...         ...
# 88878  88878  yes       88377
# 88879  88879   no       88601
# 88880  88880   no       88802
# 88881  88881   no       88816
# 88882  88882  yes       88863
#
#                                               MainBranch
# 0                 I am a student who is learning to code  \
# 1                 I am a student who is learning to code
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# ...
