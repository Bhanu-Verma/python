# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


dict={
    'name':['bhanu','ramu','vishnu'],
    'place':['etah','warangal','daman'],
    'cpi':[9.63,8.9,9.43]
}

# %%
df=pd.DataFrame(dict)
df
# Out:
#      name     place   cpi
# 0   bhanu      etah  9.63
# 1    ramu  warangal  8.90
# 2  vishnu     daman  9.43

# %%
#sorting the data frame by cpi
df.sort_values(by='cpi',ascending='True')
# Out:
#      name     place   cpi
# 0   bhanu      etah  9.63
# 1    ramu  warangal  8.90
# 2  vishnu     daman  9.43
