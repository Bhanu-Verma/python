# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# PLOTING A POINT---

# %%
plt.plot(4,5,'.')
plt.show()

# %%
x = np.array(list(i for i in range(5)))
y = np.array(list(3*j for j in x))

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y=x*3")
plt.title("graph of y=3x")
plt.show()

# %%
y = np.random.rand(100)
x = np.array(list(i for i in range(100)))

plt.scatter(x,y,c='green')

# %% [markdown]
# changing the figure size with matplotlib--

# %%
y = np.random.rand(100)
x = np.array(list(i for i in range(100)))

plt.scatter(x,y,c='green')
plt.figure(figsize=(2,2))
plt.show()

# %% [markdown]
# Create multiple plots with the help of subplot function-

# %%
#for demonstration take 100 numbers b/w 0 and 10
x = np.linspace(0,10,100)
y = np.array(list(i*i for i in x))

plt.figure(figsize=(9,2.5))


#arguments of subplot--
#131==
#1 - we have 1 row in the fugure
#3 - there are three columns
#1 - in that row and clumn fix this plot at 1st position--
plt.subplot(133)
plt.plot(x,y)



plt.subplot(132)
plt.scatter(x,y,c='b')



plt.subplot(131)
plt.bar(x,y,width=0.3)

plt.suptitle("showing the graph of y=x")
plt.show()

# %%
fig = plt.figure()
a1 = fig.add_axes([0,0,1,1]) #The calling signature of add_axes is add_axes(rect), where rect is a list [x0, y0, width, height] denoting the lower left point of the new axes in figure coodinates (x0,y0) and its width and height. So the axes is positionned in absolute coordinates on the canvas

x = np.arange(1,10)
a1.plot(x, np.exp(x),'b')

a1.set_title('range of numbers')

#explicitly set x and y limits
plt.ylim(0,10000)
plt.xlim(0,15)

#explicitly set x and y labels
plt.xlabel("x-axis") 
plt.ylabel('y-axis')
plt.show()
